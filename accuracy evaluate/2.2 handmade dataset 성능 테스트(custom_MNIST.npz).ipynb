# %%
import numpy as np
import joblib
import os
import warnings
from sklearn.exceptions import ConvergenceWarning
import time

# 1. Scikit-Learn 평가 도구 임포트
from scipy.ndimage import rotate, shift, zoom
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin, ClassifierMixin, clone

# 불필요한 경고 메시지 숨기기
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')

print("--- 1. 평가에 필요한 모듈 로드 완료 ---")
# Out:
# --- 1. 평가에 필요한 모듈 로드 완료 ---

# %%
import glob
import os

# --- 2. 파일 목록 정의 (자동 로드) ---
# 'train code' 폴더 내의 패턴에 맞는 모든 .joblib 파일을 찾습니다.
# 예: train code 폴더 안의 "..._best_0-1.joblib"로 끝나는 모든 파일
model_search_pattern = 'train code/0-1/*'
model_files = sorted(glob.glob(model_search_pattern))

# 파일이 제대로 찾아졌는지 확인
print(f"--- 총 {len(model_files)}개의 모델 파일을 찾았습니다 ---")
for f in model_files:
    print(f" -> {f}")

handmade_data_file = 'data/final_gu_latest_logic_numpy.npz'
# handmade_data_file = 'data/custom_MNIST2.npz'
# Out:
# --- 총 8개의 모델 파일을 찾았습니다 ---
#  -> train code/0-1/decision_tree_mnist_best_0-1.joblib
#  -> train code/0-1/gradient_boosting_mnist_best_0-1.joblib
#  -> train code/0-1/knn_mnist_best_0-1.joblib
#  -> train code/0-1/logistic_mnist_best_0-1.joblib
#  -> train code/0-1/mlp_classifier_mnist_best_0-1.joblib
#  -> train code/0-1/random_forest_mnist_best_0-1.joblib
#  -> train code/0-1/sgd_mnist_best_0-1.joblib
#  -> train code/0-1/svm_mnist_best_0-1.joblib

# %%
# --- 3. Hand-made 테스트 데이터 로드 ---
print(f"\n--- 2. Hand-made 테스트 데이터 '{handmade_data_file}' 로드 ---")

if not os.path.exists(handmade_data_file):
    print(f"[오류] 테스트 데이터 '{handmade_data_file}'을 찾을 수 없습니다!")
    print("-> 이전 단계에서 데이터 병합 및 저장을 먼저 실행하세요.")
else:
    with np.load(handmade_data_file, allow_pickle=True) as data:
        print(data)
        if 'img' in data and 'label' in data:
            X_test = data['img']
            y_test = data['label']
        elif 'x_train' in data and 'y_train' in data:
            X_test = data['x_train']
            y_test = data['y_train']
        elif 'images' in data and 'labels' in data:
            X_test = data['images']
            y_test = data['labels']
        else:
            X_test = data['X']
            y_test = data['y'] # 이 y_test가 "실제 정답"
            
X_test = X_test.reshape(-1, 784)

if keras:
    X_test = x_train_keras
    y_test = y_train_keras

print(f"  > 테스트 데이터 로드 성공. X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# --- 2. Hand-made 테스트 데이터 'data/custom_MNIST2.npz' 로드 ---
# NpzFile 'data/custom_MNIST2.npz' with keys: images, labels
#   > 테스트 데이터 로드 성공. X_test: (11687, 784), y_test: (11687,)

# %%
import matplotlib.pyplot as plt

# 1. 데이터 샘플 시각화 (모델에 들어가기 직전 상태 확인)
plt.figure(figsize=(10, 4))
for i in range(5):
    ax = plt.subplot(1, 5, i + 1)
    # reshape해서 이미지로 복원
    img = X_test[i].reshape(28, 28)
    plt.imshow(img, cmap='gray')
    plt.title(f"Label: {y_test[i]}\nMin:{img.min():.2f}, Max:{img.max():.2f}")
    plt.axis('off')
plt.suptitle("Check Input Data: Is it White-on-Black?", fontsize=15)
plt.show()

print("\n--- 3. 8개 모델 성능 평가 시작 ---")

results = []

for i, model_name in enumerate(model_files):
    print(f"\n=============================================")
    print(f" [{i+1}/{len(model_files)}] 평가 중: {model_name}")
    print(f"=============================================")
    
    if not os.path.exists(model_name):
        print(f"  [오류] 모델 파일 '{model_name}'을 찾을 수 없습니다! 'run_all.sh'를 먼저 실행하세요.")
        continue
        
    # 모델 로드
    model = joblib.load(model_name)
    
    # 예측 수행
    start_time = time.time()
    y_pred = model.predict(X_test)
    pred_time = time.time() - start_time
    
    # 평가
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, digits=4, zero_division=0)
    cm = confusion_matrix(y_test, y_pred, labels=np.arange(10))
    
    print(f"  > 예측 완료 (소요 시간: {pred_time:.4f}초)")
    print(f"  > **Accuracy (정확도): {accuracy * 100:.2f}%**")
    
    print("\n  --- Classification Report (정밀도/재현율/F1) ---")
    print(report)
    
    # (수정) 예측 결과(y_pred)도 함께 저장
    results.append({
        'name': model_name.replace('train code/pipeline/base/', ''),
        'accuracy': accuracy,
        'cm': cm,
        'y_pred': y_pred  # 오류 분석을 위해 예측값 저장
    })
# Out:
# --- 3. 8개 모델 성능 평가 시작 ---
#
# =============================================
#  [1/8] 평가 중: train code/0-1/decision_tree_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0096초)
#   > **Accuracy (정확도): 14.12%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.2556    0.0395    0.0684      1166
#            1     0.4628    0.0477    0.0866      1173
#            2     0.1025    0.0669    0.0810      1180
#            3     0.1499    0.2790    0.1950      1183
#            4     0.2060    0.0989    0.1336      1173
#            5     0.0889    0.0947    0.0917      1183
#            6     0.1124    0.1625    0.1329      1169
#            7     0.1549    0.5319    0.2399      1160
#            8     0.1209    0.0698    0.0885      1161
#            9     0.0935    0.0202    0.0332      1139
#
#     accuracy                         0.1412     11687
#    macro avg     0.1747    0.1411    0.1151     11687
# weighted avg     0.1749    0.1412    0.1152     11687
#
#
# =============================================
#  [2/8] 평가 중: train code/0-1/gradient_boosting_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.8502초)
#   > **Accuracy (정확도): 19.29%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.9630    0.0446    0.0852      1166
#            1     0.2464    0.5618    0.3426      1173
#            2     0.5020    0.1085    0.1784      1180
#            3     0.2860    0.1429    0.1905      1183
#            4     0.2523    0.0239    0.0436      1173
#            5     0.1282    0.4429    0.1988      1183
#            6     0.3398    0.1198    0.1771      1169
#            7     0.1454    0.3336    0.2025      1160
#            8     0.2041    0.1197    0.1509      1161
#            9     0.1761    0.0246    0.0431      1139
#
#     accuracy                         0.1929     11687
#    macro avg     0.3243    0.1922    0.1613     11687
# weighted avg     0.3246    0.1929    0.1617     11687
#
#
# =============================================
#  [3/8] 평가 중: train code/0-1/knn_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 6.7048초)
#   > **Accuracy (정확도): 14.43%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.2703    0.1201    0.1663      1166
#            1     0.1105    0.9233    0.1973      1173
#            2     0.6066    0.0627    0.1137      1180
#            3     0.4953    0.0896    0.1518      1183
#            4     0.1493    0.0341    0.0555      1173
#            5     0.2351    0.0533    0.0868      1183
#            6     0.4296    0.0496    0.0890      1169
#            7     0.3272    0.0612    0.1031      1160
#            8     0.8611    0.0267    0.0518      1161
#            9     0.2019    0.0184    0.0338      1139
#
#     accuracy                         0.1443     11687
#    macro avg     0.3687    0.1439    0.1049     11687
# weighted avg     0.3689    0.1443    0.1052     11687
#
#
# =============================================
#  [4/8] 평가 중: train code/0-1/logistic_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0281초)
#   > **Accuracy (정확도): 13.82%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.5890    0.0369    0.0694      1166
#            1     0.2296    0.2447    0.2369      1173
#            2     0.3379    0.0627    0.1058      1180
#            3     0.2148    0.0735    0.1096      1183
#            4     0.1842    0.0179    0.0326      1173
#            5     0.1033    0.7464    0.1814      1183
#            6     0.2135    0.1215    0.1549      1169
#            7     0.1737    0.0500    0.0776      1160
#            8     0.5217    0.0103    0.0203      1161
#            9     0.1481    0.0070    0.0134      1139
#
#     accuracy                         0.1382     11687
#    macro avg     0.2716    0.1371    0.1002     11687
# weighted avg     0.2715    0.1382    0.1006     11687
#
#
# =============================================
#  [5/8] 평가 중: train code/0-1/mlp_classifier_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0487초)
#   > **Accuracy (정확도): 14.14%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.6504    0.0686    0.1241      1166
#            1     0.2409    0.1245    0.1641      1173
#            2     0.3180    0.0822    0.1306      1180
#            3     0.4000    0.0558    0.0979      1183
#            4     0.3239    0.0196    0.0370      1173
#            5     0.1061    0.8495    0.1887      1183
#            6     0.1745    0.0796    0.1093      1169
#            7     0.2889    0.0560    0.0939      1160
#            8     0.4848    0.0413    0.0762      1161
#            9     0.3152    0.0255    0.0471      1139
#
#     accuracy                         0.1414     11687
#    macro avg     0.3303    0.1403    0.1069     11687
# weighted avg     0.3299    0.1414    0.1072     11687
#
#
# =============================================
#  [6/8] 평가 중: train code/0-1/random_forest_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.1473초)
#   > **Accuracy (정확도): 16.14%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.2342    0.0952    0.1354      1166
#            1     0.4510    0.2080    0.2847      1173
#            2     0.2299    0.0653    0.1017      1180
#            3     0.4548    0.1192    0.1889      1183
#            4     0.3771    0.0563    0.0979      1173
#            5     0.1995    0.1327    0.1594      1183
#            6     0.4145    0.0539    0.0954      1169
#            7     0.1060    0.7491    0.1857      1160
#            8     0.2217    0.1266    0.1612      1161
#            9     0.2200    0.0097    0.0185      1139
#
#     accuracy                         0.1614     11687
#    macro avg     0.2909    0.1616    0.1429     11687
# weighted avg     0.2914    0.1614    0.1432     11687
#
#
# =============================================
#  [7/8] 평가 중: train code/0-1/sgd_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0286초)
#   > **Accuracy (정확도): 12.55%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.4805    0.0317    0.0595      1166
#            1     0.5800    0.0989    0.1690      1173
#            2     0.2811    0.0517    0.0873      1180
#            3     0.2155    0.0938    0.1307      1183
#            4     0.1587    0.0171    0.0308      1173
#            5     0.1019    0.7861    0.1805      1183
#            6     0.1306    0.1095    0.1191      1169
#            7     0.1192    0.0353    0.0545      1160
#            8     0.4333    0.0112    0.0218      1161
#            9     0.1333    0.0088    0.0165      1139
#
#     accuracy                         0.1255     11687
#    macro avg     0.2634    0.1244    0.0870     11687
# weighted avg     0.2635    0.1255    0.0874     11687
#
#
# =============================================
#  [8/8] 평가 중: train code/0-1/svm_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0346초)
#   > **Accuracy (정확도): 13.82%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.2696    0.0266    0.0484      1166
#            1     0.1745    0.2438    0.2034      1173
#            2     0.4296    0.0492    0.0882      1180
#            3     0.2029    0.1183    0.1495      1183
#            4     0.1458    0.0119    0.0221      1173
#            5     0.1061    0.7388    0.1855      1183
#            6     0.3465    0.1052    0.1614      1169
#            7     0.2082    0.0612    0.0946      1160
#            8     0.4062    0.0112    0.0218      1161
#            9     0.1087    0.0044    0.0084      1139
#
#     accuracy                         0.1382     11687
#    macro avg     0.2398    0.1371    0.0983     11687
# weighted avg     0.2400    0.1382    0.0988     11687

# %%
# --- 5. 최종 요약 및 Confusion Matrix 시각화 ---
print("\n--- 4. 최종 성능 요약 (Accuracy 기준 내림차순) ---")

# 정확도 기준으로 결과 정렬
results_sorted = sorted(results, key=lambda x: x['accuracy'], reverse=True)

for res in results_sorted:
    print(f"  - {res['name']:<25} | Accuracy: {res['accuracy'] * 100:.2f}%")

print("\n--- 5. 8개 모델 Confusion Matrix 시각화 ---")

# 2x4 격자로 8개 Confusion Matrix 그리기
fig_cm, axes_cm = plt.subplots(2, 4, figsize=(22, 10))
fig_cm.suptitle("Confusion Matrices: Original Models vs. Hand-made Data", fontsize=20)

for i, res in enumerate(results):
    ax = axes_cm.flat[i]
    disp = ConfusionMatrixDisplay(confusion_matrix=res['cm'], display_labels=np.arange(10))
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f"{res['name']}\nAccuracy: {res['accuracy']:.3f}")
    
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

output_image_file = 'all_confusion_matrices.png'
plt.savefig(output_image_file)
print(f"\n[성공] 8개 모델의 혼동 행렬을 '{output_image_file}'로 저장했습니다.")
plt.close(fig_cm) # 메모리 해제
# Out:
# --- 4. 최종 성능 요약 (Accuracy 기준 내림차순) ---
#   - train code/0-1/gradient_boosting_mnist_best_0-1.joblib | Accuracy: 19.29%
#   - train code/0-1/random_forest_mnist_best_0-1.joblib | Accuracy: 16.14%
#   - train code/0-1/knn_mnist_best_0-1.joblib | Accuracy: 14.43%
#   - train code/0-1/mlp_classifier_mnist_best_0-1.joblib | Accuracy: 14.14%
#   - train code/0-1/decision_tree_mnist_best_0-1.joblib | Accuracy: 14.12%
#   - train code/0-1/logistic_mnist_best_0-1.joblib | Accuracy: 13.82%
#   - train code/0-1/svm_mnist_best_0-1.joblib | Accuracy: 13.82%
#   - train code/0-1/sgd_mnist_best_0-1.joblib | Accuracy: 12.55%
#
# --- 5. 8개 모델 Confusion Matrix 시각화 ---
#
# [성공] 8개 모델의 혼동 행렬을 'all_confusion_matrices.png'로 저장했습니다.

# %%
# ==========================================
# [수정 제안] 전처리 적용 후 평가하기
# ==========================================
#### --- 4. 8개 모델 순차 평가 ---

# preprocessor = CustomImagePreprocess()

# X_test = preprocessor.transform(X_test)

import matplotlib.pyplot as plt

# 1. 데이터 샘플 시각화 (모델에 들어가기 직전 상태 확인)
plt.figure(figsize=(10, 4))
for i in range(5):
    ax = plt.subplot(1, 5, i + 1)
    # reshape해서 이미지로 복원
    img = X_test[i].reshape(28, 28)
    plt.imshow(img, cmap='gray')
    plt.title(f"Label: {y_test[i]}\nMin:{img.min():.2f}, Max:{img.max():.2f}")
    plt.axis('off')
plt.suptitle("Check Input Data: Is it White-on-Black?", fontsize=15)
plt.show()

print("\n--- 3. 8개 모델 성능 평가 시작 ---")

results = []

for i, model_name in enumerate(model_files):
    print(f"\n=============================================")
    print(f" [{i+1}/{len(model_files)}] 평가 중: {model_name}")
    print(f"=============================================")
    
    if not os.path.exists(model_name):
        print(f"  [오류] 모델 파일 '{model_name}'을 찾을 수 없습니다! 'run_all.sh'를 먼저 실행하세요.")
        continue
        
    # 모델 로드
    model = joblib.load(model_name)
    
    # 예측 수행
    start_time = time.time()
    y_pred = model.predict(X_test)
    pred_time = time.time() - start_time
    
    # 평가
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, digits=4, zero_division=0)
    cm = confusion_matrix(y_test, y_pred, labels=np.arange(10))
    
    print(f"  > 예측 완료 (소요 시간: {pred_time:.4f}초)")
    print(f"  > **Accuracy (정확도): {accuracy * 100:.2f}%**")
    
    print("\n  --- Classification Report (정밀도/재현율/F1) ---")
    print(report)
    
    # (수정) 예측 결과(y_pred)도 함께 저장
    results.append({
        'name': model_name.replace('train code/pipeline/base/', ''),
        'accuracy': accuracy,
        'cm': cm,
        'y_pred': y_pred  # 오류 분석을 위해 예측값 저장
    })
# Out:
# --- 3. 8개 모델 성능 평가 시작 ---
#
# =============================================
#  [1/8] 평가 중: train code/0-1/decision_tree_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0051초)
#   > **Accuracy (정확도): 32.40%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.4562    0.1741    0.2520      1166
#            1     0.5089    0.5627    0.5344      1173
#            2     0.3060    0.3542    0.3284      1180
#            3     0.3161    0.2680    0.2900      1183
#            4     0.3002    0.2140    0.2499      1173
#            5     0.2319    0.3297    0.2723      1183
#            6     0.3503    0.4286    0.3855      1169
#            7     0.3316    0.6112    0.4300      1160
#            8     0.2689    0.1197    0.1657      1161
#            9     0.2045    0.1747    0.1884      1139
#
#     accuracy                         0.3240     11687
#    macro avg     0.3275    0.3237    0.3097     11687
# weighted avg     0.3277    0.3240    0.3100     11687
#
#
# =============================================
#  [2/8] 평가 중: train code/0-1/gradient_boosting_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 1.0063초)
#   > **Accuracy (정확도): 45.46%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.8086    0.2427    0.3734      1166
#            1     0.4214    0.8645    0.5666      1173
#            2     0.5722    0.3627    0.4440      1180
#            3     0.5201    0.5579    0.5383      1183
#            4     0.3075    0.4467    0.3643      1173
#            5     0.4471    0.6855    0.5412      1183
#            6     0.5670    0.3584    0.4392      1169
#            7     0.3903    0.6552    0.4892      1160
#            8     0.9031    0.2007    0.3284      1161
#            9     0.4004    0.1589    0.2275      1139
#
#     accuracy                         0.4546     11687
#    macro avg     0.5338    0.4533    0.4312     11687
# weighted avg     0.5337    0.4546    0.4321     11687
#
#
# =============================================
#  [3/8] 평가 중: train code/0-1/knn_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 15.7703초)
#   > **Accuracy (정확도): 45.14%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.6754    0.2890    0.4048      1166
#            1     0.4142    0.8517    0.5573      1173
#            2     0.7178    0.6983    0.7079      1180
#            3     0.5683    0.4429    0.4979      1183
#            4     0.2947    0.3444    0.3176      1173
#            5     0.4324    0.4463    0.4393      1183
#            6     0.6316    0.5030    0.5600      1169
#            7     0.3616    0.4448    0.3989      1160
#            8     0.7917    0.1964    0.3147      1161
#            9     0.2234    0.2880    0.2516      1139
#
#     accuracy                         0.4514     11687
#    macro avg     0.5111    0.4505    0.4450     11687
# weighted avg     0.5118    0.4514    0.4459     11687
#
#
# =============================================
#  [4/8] 평가 중: train code/0-1/logistic_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0371초)
#   > **Accuracy (정확도): 35.48%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.6269    0.2075    0.3119      1166
#            1     0.4431    0.7067    0.5447      1173
#            2     0.4964    0.3534    0.4129      1180
#            3     0.3005    0.3373    0.3178      1183
#            4     0.2045    0.2643    0.2306      1173
#            5     0.3127    0.2477    0.2764      1183
#            6     0.5229    0.5851    0.5523      1169
#            7     0.3397    0.5181    0.4104      1160
#            8     0.3535    0.1309    0.1911      1161
#            9     0.1690    0.1932    0.1803      1139
#
#     accuracy                         0.3548     11687
#    macro avg     0.3769    0.3544    0.3428     11687
# weighted avg     0.3773    0.3548    0.3433     11687
#
#
# =============================================
#  [5/8] 평가 중: train code/0-1/mlp_classifier_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0577초)
#   > **Accuracy (정확도): 49.53%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.6741    0.2590    0.3742      1166
#            1     0.8242    0.6633    0.7350      1173
#            2     0.5350    0.5763    0.5549      1180
#            3     0.5375    0.4548    0.4927      1183
#            4     0.3557    0.4749    0.4067      1173
#            5     0.3741    0.5765    0.4538      1183
#            6     0.6379    0.5560    0.5941      1169
#            7     0.4594    0.5897    0.5164      1160
#            8     0.5211    0.3609    0.4265      1161
#            9     0.3767    0.4372    0.4047      1139
#
#     accuracy                         0.4953     11687
#    macro avg     0.5296    0.4948    0.4959     11687
# weighted avg     0.5298    0.4953    0.4962     11687
#
#
# =============================================
#  [6/8] 평가 중: train code/0-1/random_forest_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.1503초)
#   > **Accuracy (정확도): 47.58%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.7896    0.2607    0.3920      1166
#            1     0.5046    0.8329    0.6285      1173
#            2     0.5983    0.5983    0.5983      1180
#            3     0.5520    0.4708    0.5082      1183
#            4     0.4211    0.4348    0.4279      1173
#            5     0.4158    0.6391    0.5038      1183
#            6     0.7241    0.5141    0.6013      1169
#            7     0.3379    0.6629    0.4476      1160
#            8     0.6629    0.1507    0.2456      1161
#            9     0.2648    0.1809    0.2149      1139
#
#     accuracy                         0.4758     11687
#    macro avg     0.5271    0.4745    0.4568     11687
# weighted avg     0.5277    0.4758    0.4579     11687
#
#
# =============================================
#  [7/8] 평가 중: train code/0-1/sgd_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0386초)
#   > **Accuracy (정확도): 35.26%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.6834    0.2333    0.3478      1166
#            1     0.4696    0.7306    0.5717      1173
#            2     0.4404    0.3729    0.4039      1180
#            3     0.3060    0.4074    0.3495      1183
#            4     0.2340    0.2796    0.2548      1173
#            5     0.3284    0.3542    0.3408      1183
#            6     0.4575    0.4885    0.4725      1169
#            7     0.3341    0.3879    0.3590      1160
#            8     0.3128    0.1094    0.1621      1161
#            9     0.1445    0.1536    0.1489      1139
#
#     accuracy                         0.3526     11687
#    macro avg     0.3711    0.3517    0.3411     11687
# weighted avg     0.3716    0.3526    0.3418     11687
#
#
# =============================================
#  [8/8] 평가 중: train code/0-1/svm_mnist_best_0-1.joblib
# =============================================
#   > 예측 완료 (소요 시간: 0.0472초)
#   > **Accuracy (정확도): 33.96%**
#
#   --- Classification Report (정밀도/재현율/F1) ---
#               precision    recall  f1-score   support
#
#            0     0.5969    0.2324    0.3346      1166
#            1     0.3789    0.6812    0.4869      1173
#            2     0.4514    0.2873    0.3511      1180
#            3     0.2834    0.3855    0.3266      1183
#            4     0.2111    0.2336    0.2218      1173
#            5     0.3348    0.3246    0.3296      1183
#            6     0.5536    0.5346    0.5440      1169
#            7     0.3154    0.4586    0.3737      1160
#            8     0.3134    0.1171    0.1705      1161
#            9     0.1431    0.1343    0.1386      1139
#
#     accuracy                         0.3396     11687
#    macro avg     0.3582    0.3389    0.3277     11687
# weighted avg     0.3587    0.3396    0.3283     11687

# %%
# --- 5. 최종 요약 및 Confusion Matrix 시각화 ---
print("\n--- 4. 최종 성능 요약 (Accuracy 기준 내림차순) ---")

# 정확도 기준으로 결과 정렬
results_sorted = sorted(results, key=lambda x: x['accuracy'], reverse=True)

for res in results_sorted:
    print(f"  - {res['name']:<25} | Accuracy: {res['accuracy'] * 100:.2f}%")

print("\n--- 5. 8개 모델 Confusion Matrix 시각화 ---")

# 2x4 격자로 8개 Confusion Matrix 그리기
fig_cm, axes_cm = plt.subplots(2, 4, figsize=(22, 10))
fig_cm.suptitle("Confusion Matrices: Original Models vs. Hand-made Data", fontsize=20)

for i, res in enumerate(results):
    ax = axes_cm.flat[i]
    disp = ConfusionMatrixDisplay(confusion_matrix=res['cm'], display_labels=np.arange(10))
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f"{res['name']}\nAccuracy: {res['accuracy']:.3f}")
    
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

output_image_file = 'all_confusion_matrices.png'
plt.savefig(output_image_file)
print(f"\n[성공] 8개 모델의 혼동 행렬을 '{output_image_file}'로 저장했습니다.")
plt.close(fig_cm) # 메모리 해제
# Out:
# --- 4. 최종 성능 요약 (Accuracy 기준 내림차순) ---
#   - train code/0-1/mlp_classifier_mnist_best_0-1.joblib | Accuracy: 49.53%
#   - train code/0-1/random_forest_mnist_best_0-1.joblib | Accuracy: 47.58%
#   - train code/0-1/gradient_boosting_mnist_best_0-1.joblib | Accuracy: 45.46%
#   - train code/0-1/knn_mnist_best_0-1.joblib | Accuracy: 45.14%
#   - train code/0-1/logistic_mnist_best_0-1.joblib | Accuracy: 35.48%
#   - train code/0-1/sgd_mnist_best_0-1.joblib | Accuracy: 35.26%
#   - train code/0-1/svm_mnist_best_0-1.joblib | Accuracy: 33.96%
#   - train code/0-1/decision_tree_mnist_best_0-1.joblib | Accuracy: 32.40%
#
# --- 5. 8개 모델 Confusion Matrix 시각화 ---
#
# [성공] 8개 모델의 혼동 행렬을 'all_confusion_matrices.png'로 저장했습니다.
